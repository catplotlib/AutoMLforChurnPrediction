# %% [markdown]
# # H2O's AutoML for Predictive Modeling
# Automated Machine Learning (AutoML) is revolutionizing the field of data science by making algorithms and models accessible to non-experts and improving efficiency of experts. One of the significant players in this space is H2O.ai, with their open-source platform, H2O. In this notebook, we will walk through the process of using H2O's AutoML to train a predictive model and make predictions on unseen data. We will use a customer churn dataset, where our task is to predict whether a customer will churn based on various features like their usage patterns and account characteristics.

# %% [markdown]
# ## Install the required Libraries
# Before we get started, we need to install the required Python libraries. These include the H2O library itself, as well as a few others that we'll use along the way.

# %%
# !pip install requests
# !pip install tabulate
# !pip install "colorama>=0.3.8"
# !pip install future
# Out:
# Requirement already satisfied: requests in /Applications/anaconda3/lib/python3.10/site-packages (2.28.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Applications/anaconda3/lib/python3.10/site-packages (from requests) (1.26.14)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Applications/anaconda3/lib/python3.10/site-packages (from requests) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Applications/anaconda3/lib/python3.10/site-packages (from requests) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Applications/anaconda3/lib/python3.10/site-packages (from requests) (2023.5.7)
# Requirement already satisfied: tabulate in /Applications/anaconda3/lib/python3.10/site-packages (0.8.10)
# Requirement already satisfied: colorama>=0.3.8 in /Applications/anaconda3/lib/python3.10/site-packages (0.4.6)
# Requirement already satisfied: future in /Applications/anaconda3/lib/python3.10/site-packages (0.18.3)

# %%
# !pip install h2o
# Out:
# Requirement already satisfied: h2o in /Applications/anaconda3/lib/python3.10/site-packages (3.40.0.4)
# Requirement already satisfied: future in /Applications/anaconda3/lib/python3.10/site-packages (from h2o) (0.18.3)
# Requirement already satisfied: requests in /Applications/anaconda3/lib/python3.10/site-packages (from h2o) (2.28.1)
# Requirement already satisfied: tabulate in /Applications/anaconda3/lib/python3.10/site-packages (from h2o) (0.8.10)
# Requirement already satisfied: idna<4,>=2.5 in /Applications/anaconda3/lib/python3.10/site-packages (from requests->h2o) (3.4)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Applications/anaconda3/lib/python3.10/site-packages (from requests->h2o) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Applications/anaconda3/lib/python3.10/site-packages (from requests->h2o) (2023.5.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Applications/anaconda3/lib/python3.10/site-packages (from requests->h2o) (1.26.14)

# %% [markdown]
# ## Initialize H2O and Set Up AutoML
# Once we've installed the libraries, we'll import them and initialize H2O. We'll also specify the maximum memory size to be used.

# %%
import h2o
from h2o.automl import H2OAutoML
h2o.init(max_mem_size='16G')
# Out:
# Checking whether there is an H2O instance running at http://localhost:54321. connected.
# --------------------------  ------------------------------------
# H2O_cluster_uptime:         8 hours 57 mins
# H2O_cluster_timezone:       Asia/Kolkata
# H2O_data_parsing_timezone:  UTC
# H2O_cluster_version:        3.40.0.4
# H2O_cluster_version_age:    1 month and 20 days
# H2O_cluster_name:           H2O_from_python_pujachaudhury_f8wv8n
# H2O_cluster_total_nodes:    1
# H2O_cluster_free_memory:    13.81 Gb
# H2O_cluster_total_cores:    8
# H2O_cluster_allowed_cores:  8
# H2O_cluster_status:         locked, healthy
# H2O_connection_url:         http://localhost:54321
# H2O_connection_proxy:       {"http": null, "https": null}
# H2O_internal_security:      False
# Python_version:             3.10.9 final
# --------------------------  ------------------------------------

# %% [markdown]
# ## Import Data and Set Up Variables
# Next, we'll import our dataset, take a quick look at the first few rows, and split it into a training set and a test set.

# %%
df = h2o.import_file("Ecom.csv")
# Out:
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%

# %%
df.head()
# Out:
#   CustomerID    Churn    Tenure  PreferredLoginDevice      CityTier    WarehouseToHome  PreferredPaymentMode    Gender      HourSpendOnApp    NumberOfDeviceRegistered  PreferedOrderCat      SatisfactionScore  MaritalStatus      NumberOfAddress    Complain    OrderAmountHikeFromlastYear    CouponUsed    OrderCount    DaySinceLastOrder    CashbackAmount
# ------------  -------  --------  ----------------------  ----------  -----------------  ----------------------  --------  ----------------  --------------------------  ------------------  -------------------  ---------------  -----------------  ----------  -----------------------------  ------------  ------------  -------------------  ----------------
#        50001        1         4  Mobile Phone                     3                  6  Debit Card              Female                   3                           3  Laptop & Accessory                    2  Single                           9           1                             11             1             1                    5               160
#        50002        1       nan  Phone                            1                  8  UPI                     Male                     3                           4  Mobile                                3  Single                           7           1                             15             0             1                    0               121
#        50003        1       nan  Phone                            1                 30  Debit Card              Male                     2                           4  Mobile                                3  Single                           6           1                             14             0             1                    3               120
#        50004        1         0  Phone                            3                 15  Debit Card              Male                     2                           4  Laptop & Accessory                    5  Single                           8           0                             23             0             1                    3               134
#        50005        1         0  Phone                            1                 12  CC                      Male                   nan                           3  Mobile                                5  Single                           3           0                             11             1             1                    3               130
#        50006        1         0  Computer                         1                 22  Debit Card              Female                   3                           5  Mobile Phone                          5  Single                           2           1                             22             4             6                    7               139
#        50007        1       nan  Phone                            3                 11  Cash on Delivery        Male                     2                           3  Laptop & Accessory                    2  Divorced                         4           0                             14             0             1                    0               121
#        50008        1       nan  Phone                            1                  6  CC                      Male                     3                           3  Mobile                                2  Divorced                         3           1                             16             2             2                    0               123
#        50009        1        13  Phone                            3                  9  E wallet                Male                   nan                           4  Mobile                                3  Divorced                         2           1                             14             0             1                    2               127
#        50010        1       nan  Phone                            1                 31  Debit Card              Male                     2                           5  Mobile                                3  Single                           2           0                             12             1             1                    1               123
# [10 rows x 20 columns]

# %%
df_train,df_test= df.split_frame(ratios=[.8])

# %%
df_train
# Out:
#   CustomerID    Churn    Tenure  PreferredLoginDevice      CityTier    WarehouseToHome  PreferredPaymentMode    Gender      HourSpendOnApp    NumberOfDeviceRegistered  PreferedOrderCat      SatisfactionScore  MaritalStatus      NumberOfAddress    Complain    OrderAmountHikeFromlastYear    CouponUsed    OrderCount    DaySinceLastOrder    CashbackAmount
# ------------  -------  --------  ----------------------  ----------  -----------------  ----------------------  --------  ----------------  --------------------------  ------------------  -------------------  ---------------  -----------------  ----------  -----------------------------  ------------  ------------  -------------------  ----------------
#        50001        1         4  Mobile Phone                     3                  6  Debit Card              Female                   3                           3  Laptop & Accessory                    2  Single                           9           1                             11             1             1                    5               160
#        50002        1       nan  Phone                            1                  8  UPI                     Male                     3                           4  Mobile                                3  Single                           7           1                             15             0             1                    0               121
#        50003        1       nan  Phone                            1                 30  Debit Card              Male                     2                           4  Mobile                                3  Single                           6           1                             14             0             1                    3               120
#        50004        1         0  Phone                            3                 15  Debit Card              Male                     2                           4  Laptop & Accessory                    5  Single                           8           0                             23             0             1                    3               134
#        50006        1         0  Computer                         1                 22  Debit Card              Female                   3                           5  Mobile Phone                          5  Single                           2           1                             22             4             6                    7               139
#        50007        1       nan  Phone                            3                 11  Cash on Delivery        Male                     2                           3  Laptop & Accessory                    2  Divorced                         4           0                             14             0             1                    0               121
#        50010        1       nan  Phone                            1                 31  Debit Card              Male                     2                           5  Mobile                                3  Single                           2           0                             12             1             1                    1               123
#        50013        1         0  Phone                            1                 11  COD                     Male                     2                           3  Mobile                                3  Single                           2           1                             13             2             2                    2               134
#        50014        1         0  Phone                            1                 15  CC                      Male                     3                           4  Mobile                                3  Divorced                         1           1                             17             0             1                    0               134
#        50015        1         9  Mobile Phone                     3                 15  Credit Card             Male                     3                           4  Fashion                               2  Single                           2           0                             16             0             4                    7               196
# [4524 rows x 20 columns]

# %% [markdown]
# We'll then specify our target variable and the input features. In this case, our target variable is 'Churn', and the features are all the other columns in the dataframe except for 'CustomerID'.

# %%
y = "Churn"  ## dependent variable
x = df.columns  ## Independent variable
x.remove(y)
x.remove('CustomerID')

# %% [markdown]
# ## Train AutoML Model
# Now we're ready to train our model. We'll specify a few parameters for the AutoML function, such as the maximum runtime, the maximum number of models to train, and the number of folds for cross-validation.

# %%
aml = H2OAutoML(max_runtime_secs=500,max_models = 15, seed = 7, verbosity="info", nfolds=4)

# %%
aml.train(x=x,y=y, training_frame=df_train)
# Out:
# AutoML progress: |
# 04:02:18.867: Project: AutoML_6_20230618_40218
# 04:02:18.869: Setting stopping tolerance adaptively based on the training frame: 0.014867525836251314
# 04:02:18.869: Build control seed: 7
# 04:02:18.874: training frame: Frame key: AutoML_6_20230618_40218_training_py_3_sid_ba79    cols: 20    rows: 4524  chunks: 32    size: 212881  checksum: 7254733612136558130
# 04:02:18.876: validation frame: NULL
# 04:02:18.876: leaderboard frame: NULL
# 04:02:18.876: blending frame: NULL
# 04:02:18.876: response column: Churn
# 04:02:18.876: fold column: null
# 04:02:18.876: weights column: null
# 04:02:18.892: Loading execution steps: [{XGBoost : [def_2 (1g, 10w), def_1 (2g, 10w), def_3 (3g, 10w), grid_1 (4g, 90w), lr_search (7g, 30w)]}, {GLM : [def_1 (1g, 10w)]}, {DRF : [def_1 (2g, 10w), XRT (3g, 10w)]}, {GBM : [def_5 (1g, 10w), def_2 (2g, 10w), def_3 (2g, 10w), def_4 (2g, 10w), def_1 (3g, 10w), grid_1 (4g, 60w), lr_annealing (7g, 10w)]}, {DeepLearning : [def_1 (3g, 10w), grid_1 (4g, 30w), grid_2 (5g, 30w), grid_3 (5g, 30w)]}, {completion : [resume_best_grids (6g, 60w)]}, {StackedEnsemble : [monotonic (9g, 10w), best_of_family_xglm (10g, 10w), all_xglm (10g, 10w)]}]
# 04:02:18.923: AutoML job created: 2023.06.18 04:02:18.844
# 04:02:18.925: AutoML build started: 2023.06.18 04:02:18.923
# 04:02:18.955: AutoML: starting XGBoost_1_AutoML_6_20230618_40218 model training
# 04:02:18.957: _response param, We have detected that your response column has only 2 unique values (0/1). If you wish to train a binary model instead of a regression model, convert your target column to categorical before training.
#
# ███
# 04:02:31.407: New leader: XGBoost_1_AutoML_6_20230618_40218, rmse: 0.20547165247844246
# 04:02:31.422: AutoML: starting GLM_1_AutoML_6_20230618_40218 model training
# 04:02:31.425: _response param, We have detected that your response column has only 2 unique values (0/1). If you wish to train a binary model instead of a regression model, convert your target column to categorical before training.
# 04:02:32.429: AutoML: starting GBM_1_AutoML_6_20230618_40218 model training
# 04:02:32.432: _response param, We have detected that your response column has only 2 unique values (0/1). If you wish to train a binary model instead of a regression model, convert your target column to categorical before training.
#
# ██
# 04:02:40.684: AutoML: starting XGBoost_2_AutoML_6_20230618_40218 model training
# 04:02:40.689: _response param, We have detected that your response column has only 2 unique values (0/1). If you wish to train a binary model instead of a regression model, convert your target column to categorical before training.
#
# █
# 04:02:49.673: AutoML: starting DRF_1_AutoML_6_20230618_40218 model training
# 04:02:49.676: _response param, We have detected that your response column has only 2 unique values (0/1). If you wish to train a binary model instead of a regression model, convert your target column to categorical before training.
#
# █
# 04:02:54.568: New leader: DRF_1_AutoML_6_20230618_40218, rmse: 0.20007038964613513
# 04:02:54.593: AutoML: starting GBM_2_AutoML_6_20230618_40218 model training
# 04:02:54.596: _response param, We have detected that your response column has only 2 unique values (0/1). If you wish to train a binary model instead of a regression model, convert your target column to categorical before training.
#
# ██
# 04:03:13.917: New leader: GBM_2_AutoML_6_20230618_40218, rmse: 0.1962774992710819
# 04:03:13.964: AutoML: starting GBM_3_AutoML_6_20230618_40218 model training
# 04:03:13.966: _response param, We have detected that your response column has only 2 unique values (0/1). If you wish to train a binary model instead of a regression model, convert your target column to categorical before training.
#
# ██
# 04:03:36.282: New leader: GBM_3_AutoML_6_20230618_40218, rmse: 0.1881467196675003
# 04:03:36.324: AutoML: starting GBM_4_AutoML_6_20230618_40218 model training
# 04:03:36.328: _response param, We have detected that your response column has only 2 unique values (0/1). If you wish to train a binary model instead of a regression model, convert your target column to categorical before training.
#
# ████
# 04:04:09.467: New leader: GBM_4_AutoML_6_20230618_40218, rmse: 0.1817171413135657
# 04:04:09.554: AutoML: starting XGBoost_3_AutoML_6_20230618_40218 model training
# 04:04:09.555: _response param, We have detected that your response column has only 2 unique values (0/1). If you wish to train a binary model instead of a regression model, convert your target column to categorical before training.
#
# ██
# 04:04:27.177: AutoML: starting XRT_1_AutoML_6_20230618_40218 model training
# 04:04:27.178: _response param, We have detected that your response column has only 2 unique values (0/1). If you wish to train a binary model instead of a regression model, convert your target column to categorical before training.
#
# ███
# 04:04:47.607: AutoML: starting GBM_5_AutoML_6_20230618_40218 model training
# 04:04:47.609: _response param, We have detected that your response column has only 2 unique values (0/1). If you wish to train a binary model instead of a regression model, convert your target column to categorical before training.
#
# ██
# 04:05:04.536: AutoML: starting DeepLearning_1_AutoML_6_20230618_40218 model training
# 04:05:04.537: _response param, We have detected that your response column has only 2 unique values (0/1). If you wish to train a binary model instead of a regression model, convert your target column to categorical before training.
#
#
# 04:05:05.839: AutoML: starting XGBoost_grid_1_AutoML_6_20230618_40218 hyperparameter search
#
# █
# 04:05:13.732: AutoML: starting GBM_grid_1_AutoML_6_20230618_40218 hyperparameter search
#
# ███████
# 04:05:33.897: No base models, due to timeouts or the exclude_algos option. Skipping StackedEnsemble 'monotonic'.
# 04:05:33.920: AutoML: starting StackedEnsemble_BestOfFamily_1_AutoML_6_20230618_40218 model training
# 04:05:33.921: _response param, We have detected that your response column has only 2 unique values (0/1). If you wish to train a binary model instead of a regression model, convert your target column to categorical before training.
# 04:05:35.90: New leader: StackedEnsemble_BestOfFamily_1_AutoML_6_20230618_40218, rmse: 0.18019292153485153
# 04:05:35.95: AutoML: starting StackedEnsemble_AllModels_1_AutoML_6_20230618_40218 model training
# 04:05:35.96: _response param, We have detected that your response column has only 2 unique values (0/1). If you wish to train a binary model instead of a regression model, convert your target column to categorical before training.
#
# █████████████████████████████████| (done) 100%
#
# 04:05:36.553: New leader: StackedEnsemble_AllModels_1_AutoML_6_20230618_40218, rmse: 0.17968848627515818
# 04:05:36.555: Actual modeling steps: [{XGBoost : [def_2 (1g, 10w)]}, {GLM : [def_1 (1g, 10w)]}, {GBM : [def_5 (1g, 10w)]}, {XGBoost : [def_1 (2g, 10w)]}, {DRF : [def_1 (2g, 10w)]}, {GBM : [def_2 (2g, 10w), def_3 (2g, 10w), def_4 (2g, 10w)]}, {XGBoost : [def_3 (3g, 10w)]}, {DRF : [XRT (3g, 10w)]}, {GBM : [def_1 (3g, 10w)]}, {DeepLearning : [def_1 (3g, 10w)]}, {XGBoost : [grid_1 (4g, 90w)]}, {GBM : [grid_1 (4g, 60w)]}, {StackedEnsemble : [best_of_family_xglm (10g, 10w), all_xglm (10g, 10w)]}]
# 04:05:36.565: AutoML build stopped: 2023.06.18 04:05:36.555
# 04:05:36.565: AutoML build done: built 15 models
# 04:05:36.565: AutoML duration:  3 min 17.632 sec
# Model Details
# =============
# H2OStackedEnsembleEstimator : Stacked Ensemble
# Model Key: StackedEnsemble_AllModels_1_AutoML_6_20230618_40218
#
#
# Model Summary for Stacked Ensemble:
# key                                        value
# -----------------------------------------  ----------------
# Stacking strategy                          cross_validation
# Number of base models (used / total)       5/15
# # GBM base models (used / total)           2/6
# # XGBoost base models (used / total)       2/5
# # DRF base models (used / total)           1/2
# # DeepLearning base models (used / total)  0/1
# # GLM base models (used / total)           0/1
# Metalearner algorithm                      GLM
# Metalearner fold assignment scheme         Random
# Metalearner nfolds                         4
# Metalearner fold_column
# Custom metalearner hyperparameters         None
#
# ModelMetricsRegressionGLM: stackedensemble
# ** Reported on train data. **
#
# MSE: 0.0011154647076986406
# RMSE: 0.03339857343807727
# MAE: 0.023723825093106134
# RMSLE: 0.025018222574377767
# Mean Residual Deviance: 0.0011154647076986406
# R^2: 0.9920277271938465
# Null degrees of freedom: 4523
# Residual degrees of freedom: 4518
# Null deviance: 632.9891688770997
# Residual deviance: 5.046362337628651
# AIC: -17903.786594066834
#
# ModelMetricsRegressionGLM: stackedensemble
# ** Reported on cross-validation data. **
#
# MSE: 0.03228795209985771
# RMSE: 0.17968848627515818
# MAE: 0.09318905200700987
# RMSLE: 0.128750977612639
# Mean Residual Deviance: 0.03228795209985771
# R^2: 0.769236659200851
# Null degrees of freedom: 4523
# Residual degrees of freedom: 4518
# Null deviance: 633.2643046169642
# Residual deviance: 146.07069529975627
# AIC: -2678.612650933088
#
# Cross-Validation Metrics Summary:
#                         mean       sd          cv_1_valid    cv_2_valid    cv_3_valid    cv_4_valid
# ----------------------  ---------  ----------  ------------  ------------  ------------  ------------
# mae                     0.0930765  0.00474275  0.0985117     0.0888732     0.0955842     0.089337
# mean_residual_deviance  0.0323132  0.00251173  0.0358759     0.0299873     0.0315239     0.0318657
# mse                     0.0323132  0.00251173  0.0358759     0.0299873     0.0315239     0.0318657
# null_deviance           158.316    3.13264     159.505       153.646       160.338       159.775
# r2                      0.769181   0.0134369   0.75024       0.769403      0.780499      0.77658
# residual_deviance       36.5044    2.22228     39.8223       35.325        35.1807       35.6896
# rmse                    0.179659   0.00690339  0.189409      0.173168      0.17755       0.17851
# rmsle                   0.128693   0.00410455  0.134608      0.125125      0.127694      0.127344
#
# [tips]
# Use `model.explain()` to inspect the model.
# --
# Use `h2o.display.toggle_user_tips()` to switch on/off this section.

# %% [markdown]
# Once the model is trained, we c  an view the leaderboard, which is a table that displays the performance of all the models that AutoML has trained.

# %%
lb = aml.leaderboard

# %%
lb
# Out:
# model_id                                                    rmse        mse        mae     rmsle    mean_residual_deviance
# ------------------------------------------------------  --------  ---------  ---------  --------  ------------------------
# StackedEnsemble_AllModels_1_AutoML_6_20230618_40218     0.179688  0.032288   0.0931891  0.128751                 0.032288
# StackedEnsemble_BestOfFamily_1_AutoML_6_20230618_40218  0.180193  0.0324695  0.0937873  0.129205                 0.0324695
# GBM_4_AutoML_6_20230618_40218                           0.181717  0.0330211  0.0972626  0.130253                 0.0330211
# GBM_3_AutoML_6_20230618_40218                           0.188147  0.0353992  0.103258   0.134788                 0.0353992
# GBM_2_AutoML_6_20230618_40218                           0.196277  0.0385249  0.111302   0.140603                 0.0385249
# DRF_1_AutoML_6_20230618_40218                           0.20007   0.0400282  0.109469   0.140022                 0.0400282
# GBM_5_AutoML_6_20230618_40218                           0.20153   0.0406145  0.111857   0.143754                 0.0406145
# XGBoost_1_AutoML_6_20230618_40218                       0.205472  0.0422186  0.117884   0.153185                 0.0422186
# XGBoost_2_AutoML_6_20230618_40218                       0.206981  0.0428412  0.115222   0.153181                 0.0428412
# GBM_grid_1_AutoML_6_20230618_40218_model_1              0.207316  0.04298    0.127282   0.149832                 0.04298
# [17 rows x 6 columns]

# %%
model_ids = list(aml.leaderboard['model_id'].as_data_frame().iloc[:,0])

# %%
model_ids
# Out:
# ['StackedEnsemble_AllModels_1_AutoML_6_20230618_40218',
#  'StackedEnsemble_BestOfFamily_1_AutoML_6_20230618_40218',
#  'GBM_4_AutoML_6_20230618_40218',
#  'GBM_3_AutoML_6_20230618_40218',
#  'GBM_2_AutoML_6_20230618_40218',
#  'DRF_1_AutoML_6_20230618_40218',
#  'GBM_5_AutoML_6_20230618_40218',
#  'XGBoost_1_AutoML_6_20230618_40218',
#  'XGBoost_2_AutoML_6_20230618_40218',
#  'GBM_grid_1_AutoML_6_20230618_40218_model_1',
#  'XGBoost_3_AutoML_6_20230618_40218',
#  'XRT_1_AutoML_6_20230618_40218',
#  'GBM_1_AutoML_6_20230618_40218',
#  'XGBoost_grid_1_AutoML_6_20230618_40218_model_2',
#  'XGBoost_grid_1_AutoML_6_20230618_40218_model_1',
#  'DeepLearning_1_AutoML_6_20230618_40218',
#  'GLM_1_AutoML_6_20230618_40218']

# %%
aml.leader.model_performance(df_test)
# Out:
# ModelMetricsRegressionGLM: stackedensemble
# ** Reported on test data. **
#
# MSE: 0.014969774142873413
# RMSE: 0.12235102836867949
# MAE: 0.06426821704652201
# RMSLE: 0.08869978445533803
# Mean Residual Deviance: 0.014969774142873413
# R^2: 0.8934463370238989
# Null degrees of freedom: 1105
# Residual degrees of freedom: 1100
# Null deviance: 155.38328453181424
# Residual deviance: 16.556570202017994
# AIC: -1494.4126823380511

# %%
aml.leader
# Out:
# Model Details
# =============
# H2OStackedEnsembleEstimator : Stacked Ensemble
# Model Key: StackedEnsemble_AllModels_1_AutoML_6_20230618_40218
#
#
# Model Summary for Stacked Ensemble:
# key                                        value
# -----------------------------------------  ----------------
# Stacking strategy                          cross_validation
# Number of base models (used / total)       5/15
# # GBM base models (used / total)           2/6
# # XGBoost base models (used / total)       2/5
# # DRF base models (used / total)           1/2
# # DeepLearning base models (used / total)  0/1
# # GLM base models (used / total)           0/1
# Metalearner algorithm                      GLM
# Metalearner fold assignment scheme         Random
# Metalearner nfolds                         4
# Metalearner fold_column
# Custom metalearner hyperparameters         None
#
# ModelMetricsRegressionGLM: stackedensemble
# ** Reported on train data. **
#
# MSE: 0.0011154647076986406
# RMSE: 0.03339857343807727
# MAE: 0.023723825093106134
# RMSLE: 0.025018222574377767
# Mean Residual Deviance: 0.0011154647076986406
# R^2: 0.9920277271938465
# Null degrees of freedom: 4523
# Residual degrees of freedom: 4518
# Null deviance: 632.9891688770997
# Residual deviance: 5.046362337628651
# AIC: -17903.786594066834
#
# ModelMetricsRegressionGLM: stackedensemble
# ** Reported on cross-validation data. **
#
# MSE: 0.03228795209985771
# RMSE: 0.17968848627515818
# MAE: 0.09318905200700987
# RMSLE: 0.128750977612639
# Mean Residual Deviance: 0.03228795209985771
# R^2: 0.769236659200851
# Null degrees of freedom: 4523
# Residual degrees of freedom: 4518
# Null deviance: 633.2643046169642
# Residual deviance: 146.07069529975627
# AIC: -2678.612650933088
#
# Cross-Validation Metrics Summary:
#                         mean       sd          cv_1_valid    cv_2_valid    cv_3_valid    cv_4_valid
# ----------------------  ---------  ----------  ------------  ------------  ------------  ------------
# mae                     0.0930765  0.00474275  0.0985117     0.0888732     0.0955842     0.089337
# mean_residual_deviance  0.0323132  0.00251173  0.0358759     0.0299873     0.0315239     0.0318657
# mse                     0.0323132  0.00251173  0.0358759     0.0299873     0.0315239     0.0318657
# null_deviance           158.316    3.13264     159.505       153.646       160.338       159.775
# r2                      0.769181   0.0134369   0.75024       0.769403      0.780499      0.77658
# residual_deviance       36.5044    2.22228     39.8223       35.325        35.1807       35.6896
# rmse                    0.179659   0.00690339  0.189409      0.173168      0.17755       0.17851
# rmsle                   0.128693   0.00410455  0.134608      0.125125      0.127694      0.127344
#
# [tips]
# Use `model.explain()` to inspect the model.
# --
# Use `h2o.display.toggle_user_tips()` to switch on/off this section.

# %% [markdown]
# ## Making Predictions on the Test Data
# Finally, we'll use our trained model to make predictions on the test data.

# %%
pred = aml.predict(df_test)
pred.head()
# Out:
# stackedensemble prediction progress: |███████████████████████████████████████████| (done) 100%
#    predict
# ----------
#  0.75434
#  0.815013
#  0.819143
#  0.91465
#  0.925408
#  0.0505852
#  0.566787
#  0.013585
# -0.0233839
#  0.147007
# [10 rows x 1 column]

# %% [markdown]
# And there you have it! You've trained a predictive model using H2O's AutoML and made predictions on unseen data. We encourage you to try H2O's AutoML on your own projects and experiment with the different parameters to see how they affect the model's performance. Happy modeling!
